# %% [raw]
# START
#
# INPUT name1
# INPUT age1
#
# INPUT name2
# INPUT age2
#
# temp = age1
# age1 = age2
# age2 = temp
#
# PRINT name1, age1
# PRINT name2, age2
#
# END

# %% [markdown]
# ![FLOWCHART FOR AGE SWAP.jpeg](attachment:04704aa1-7573-4634-9c8f-0bb820bb9379.jpeg)
