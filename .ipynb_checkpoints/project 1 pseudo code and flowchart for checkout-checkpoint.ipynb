# %%
START

total = 0

while True:
    scan_item()
    price = get_price()
    total = total + price
    
    more = input("More items? (yes/no): ")
    
    if more == "no":
        break

print("Total amount:", total)

payment = float(input("Enter payment amount: "))

if payment >= total:
    change = payment - total
    print("Give change:", change)
    print("Print receipt")
else:
    print("Ask for balance")

END

# %% [markdown]
# ![store checkout flowchart.png](attachment:3dc805f9-eb45-4443-9d4d-70c6fe185685.png)
